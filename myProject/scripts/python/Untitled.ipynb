# %%
import pandas as pd
import geopy.distance

df = pd.read_csv('airport_iata.csv')

# %%
df
# Out:
#          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
# 57418  ZZ-0001        heliport                     Sealand Helipad
# 57419  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 57420     ZZZZ   small_airport             Satsuma IÅjima Airport
#
#        elevation_ft continent iso_country iso_region      municipality  \
# 0              11.0       NaN          US      US-PA          Bensalem
# ...

# %%
# coords = (-59.457273, -10.188278)
# item = df.loc[df['coordinates'] == coords, 'name'].item()

# df.loc[df['coordinates'] == '126.45099639892578, 37.46910095214844']
# df.dtypes
# df.loc[df['iata_code'] == 'BGY', 'coordinates'].item()

x= (((126.45099639892578, 37.46910095214844), 'Incheon International Airport'), ((-82.70939636230001, 34.4945983887), 'Anderson Regional Airport'))

# %%
"response" : {
  "statusCode": 200,
  "Distance": 2544.4103015885285,
  "Possible routes": [
    [
      8107.321319940902,
      [
        "Malpensa International Airport",
        "Incheon International Airport"
      ]
    ],
    [
      8107.321319940902,
      [
        "Malpensa International Airport",
        "Incheon International Airport"
      ]
    ],
    [
      0,
      [
        "Malpensa International Airport",
        "Malpensa International Airport"
      ]
    ],
    [
      6327.080508833319,
      [
        "Malpensa International Airport",
        "Anderson Regional Airport"
      ]
    ],
    [
      4552.201415088247,
      [
        "Malpensa International Airport",
        "Pinto Martins International Airport"
      ]
    ],
    [
      6027.873565201604,
      [
        "Malpensa International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      6027.873565201604,
      [
        "Malpensa International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      4776.977336273064,
      [
        "Malpensa International Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      0,
      [
        "Incheon International Airport",
        "Incheon International Airport"
      ]
    ],
    [
      8107.321319940902,
      [
        "Incheon International Airport",
        "Malpensa International Airport"
      ]
    ],
    [
      10421.195615456476,
      [
        "Incheon International Airport",
        "Anderson Regional Airport"
      ]
    ],
    [
      10244.511810236621,
      [
        "Incheon International Airport",
        "Pinto Martins International Airport"
      ]
    ],
    [
      10737.164940277917,
      [
        "Incheon International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      10737.164940277917,
      [
        "Incheon International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      10378.855540204553,
      [
        "Incheon International Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      8107.321319940902,
      [
        "Incheon International Airport",
        "Malpensa International Airport"
      ]
    ],
    [
      10421.195615456476,
      [
        "Incheon International Airport",
        "Anderson Regional Airport"
      ]
    ],
    [
      10244.511810236621,
      [
        "Incheon International Airport",
        "Pinto Martins International Airport"
      ]
    ],
    [
      10737.164940277917,
      [
        "Incheon International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      10737.164940277917,
      [
        "Incheon International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      10378.855540204553,
      [
        "Incheon International Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      6327.080508833319,
      [
        "Malpensa International Airport",
        "Anderson Regional Airport"
      ]
    ],
    [
      4552.201415088247,
      [
        "Malpensa International Airport",
        "Pinto Martins International Airport"
      ]
    ],
    [
      6027.873565201604,
      [
        "Malpensa International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      6027.873565201604,
      [
        "Malpensa International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      4776.977336273064,
      [
        "Malpensa International Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      3171.6834127037946,
      [
        "Anderson Regional Airport",
        "Pinto Martins International Airport"
      ]
    ],
    [
      366.0308435880946,
      [
        "Anderson Regional Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      366.0308435880946,
      [
        "Anderson Regional Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      2884.929146007446,
      [
        "Anderson Regional Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      2825.904413801137,
      [
        "Pinto Martins International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      2825.904413801137,
      [
        "Pinto Martins International Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      303.9960842965677,
      [
        "Pinto Martins International Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      0,
      [
        "Clarence A. Bain Airport",
        "Clarence A. Bain Airport"
      ]
    ],
    [
      2544.4103015885285,
      [
        "Clarence A. Bain Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ],
    [
      2544.4103015885285,
      [
        "Clarence A. Bain Airport",
        "Senador PetrÃ´nio Portela Airport"
      ]
    ]
  ],
  "StartPoint": 0,
  "EndPoint": 0
}
# Out:
# 'Incheon International Airport'

# %%
df = df[df.type != 'closed']
df = df[df.type != 'small_airport'] 
df = df[df.type != 'heliport']
df = df[df.type != 'seaplane_base']
df = df[df.type != 'balloonport']
df
# Out:
#          ident            type                                name  \
# 6220       5A8  medium_airport             Aleknagik / New Airport
# 10464  AF-0005  medium_airport  Khost International Airport (U.C.)
# 10489     AGGH  medium_airport       Honiara International Airport
# 10494     AGGM  medium_airport                       Munda Airport
# 10516      AHJ  medium_airport                    Hongyuan Airport
# ...        ...             ...                                 ...
# 57413     ZYTN  medium_airport           Tonghua Sanyuanpu Airport
# 57414     ZYTX   large_airport                     Taoxian Airport
# 57415     ZYYJ  medium_airport         Yanji Chaoyangchuan Airport
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
#
#        elevation_ft continent iso_country iso_region municipality gps_code  \
# 6220           66.0       NaN          US      US-AK    Aleknagik      5A8
# ...

# %%
df.loc[df['coordinates'] == '8.72811, 45.6306', 'name']
# Out:
# 33016    Malpensa International Airport
# Name: name, dtype: object

# %%
df = df[df['iata_code'].notna()]
df[df['iata_code'].str.len() == 2]
# Out:
# Empty DataFrame
# Columns: [ident, type, name, elevation_ft, continent, iso_country, iso_region, municipality, gps_code, iata_code, local_code, coordinates]
# Index: []

# %%
# df = df.drop(df[df.iata_code == 'NaN'].index, inplace=True)


##### look for value in df
# 45.6696° N, 9.7036° E
def find_airport_coord(x):
#     x = 'BGY'
    item = df.loc[df['iata_code'] == x, 'coordinates'].item()
    coords = item.split(',')
    coords = [float(s) for s in coords]
    coords = (coords[0], coords[1])
    return coords

xx = find_airport_coord('BGY')
type(xx)
# Out:
# tuple

# %%
pip install geopy
# Out:
# ...
#      |████████████████████████████████| 118 kB 5.3 MB/s
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
coords_1 = find_airport_coord('LIS')
coords_2 = find_airport_coord('MXP')

distance = geopy.distance.distance(coords_1, coords_2).km
distance
# Out:
# 2116.389151241743

# %%
doc = 'boarding-pass-2.pdf'
f = doc.split('.', 1)[1].lower()

# %%
f == 'pdf'
# Out:
# True

# %%
body = "{\"DATA DEL VIAGGIO / TRAVEL DATE \": \"24 JUL 2021 \", \"ORARIO DI CHIUSURA USCITA DI IMBARCO / GATE CLOSES \": \"10:45 \", \"POSTO NUMERO / SEAT NUMBER \": \"21E \", \"PASSEGGERO / PASSENGER \": \"VICINI, ALESSANDRA Sig.a \", \"NUMERO DEL VOLO / FLIGHT NUMBER \": \"EJU2717 \", \"A / TO \": \"(LIS) Lisbona (T2) \", \"DA / FROM \": \"(MXP) Milano Malpensa (T1) \", \"ORARIO DI PARTENZA DEL VOLO / FLIGHT DEPARTS \": \"11:15 \"}"
body = body.split(" ")

# %%
df.loc[df['iata_code'] == 'LIS', 'name'].item()
# Out:
# 'Humberto Delgado Airport (Lisbon Portela Airport)'

# %%
spec_chars = "\.[]{}()<>*+-=!?^$|/:,\""
new_body = []
for x in body:
#     print(x)
    for c in spec_chars:
        x = x.replace(c, "")
    new_body.append(x.lower())

# %%
coords = []
for x in new_body:
    if len(x) == 3 and x.upper() in df.iata_code.values:
#         print(airport)
        airport = df.loc[df['iata_code'] == x.upper(), 'name'].item()
        airport_list = airport.split(" ")
        for name in airport_list:
            for char in spec_chars:
                name = name.replace(char, "")
            print(name)
#             print(new_body)
            if name.lower() in new_body:
                print(name)
                r = find_airport_coord(x.upper())
                print(r)
                if r not in coords:
                    coords.append((r,airport))
                    break
distances = []
if len(coords) == 2:
    distance = geopy.distance.distance(coords[0][0], coords[1][0]).km
    print("Distance: " + distance + "from " + coords[0][1] + "to " + coords[1][1])
elif len(coords) < 2:
    print("we could not find your trip points")
else:
    
    for i in coords:
        for j in coords:
            if i != j:
                distances.append((geopy.distance.distance(coords[i][0], coords[j][0]).km, (coords[i][1], coords[j][1])))
                
                
                
distances
# Out:
# Indira
# Gandhi
# International
# Airport
# Inca
# Manco
# Capac
# International
# Airport
# Indira
# Gandhi
# International
# Airport
# Humberto
# Delgado
# Airport
# Lisbon
# Portela
# Airport
# Malpensa
# Malpensa
# (8.72811, 45.6306)
# Indira
# Gandhi
# International
# Airport
# we could not find your trip points
# []

# %%
coords[0][0][0]
# Out:
# 8.72811

# %%
body = {"Validity : ": "-09JUN20 ", "Fare Basis : ": "ULEOZRUK/5 ", "SKYPASS Miles : ": "5,509 ", "Status : ": "OK (Confirmed) ", "Aircraft Type : ": "Boeing 777-300ER ", "Flight Duration : ": "11H 40M ", "Booking Reference ": "88347367 (RG2S7L) ", "Baggage : ": "1 Piece ", "Terminal No : ": "1 ", "Class : ": "K (Economy) ", "Flight ": "KE 928 ", "Passenger Name ": "GALLIDABINO/ANDREAPAOLO MR ", "Seoul/Incheon(Incheon) ": "16JUN19(SUN) 15:05 (Local Time) ", "Milan (Malpensa) ": "16JUN19(SUN) 19:45 (Local ", "Seat number : ": "", "ICN ": "Seoul/Incheon(Incheon) 10JUN19(MON) 16:00 (Local ", "Ticket Number ": "1802326906507 ", "Operated by KE ": "X KSREANAIR ", "From ": "", "Itinerary ": "From "}

# %%
type(body)
# Out:
# dict

# %%
import json
json.dumps(body)
# Out:
# '{"Validity : ": "-09JUN20 ", "Fare Basis : ": "ULEOZRUK/5 ", "SKYPASS Miles : ": "5,509 ", "Status : ": "OK (Confirmed) ", "Aircraft Type : ": "Boeing 777-300ER ", "Flight Duration : ": "11H 40M ", "Booking Reference ": "88347367 (RG2S7L) ", "Baggage : ": "1 Piece ", "Terminal No : ": "1 ", "Class : ": "K (Economy) ", "Flight ": "KE 928 ", "Passenger Name ": "GALLIDABINO/ANDREAPAOLO MR ", "Seoul/Incheon(Incheon) ": "16JUN19(SUN) 15:05 (Local Time) ", "Milan (Malpensa) ": "16JUN19(SUN) 19:45 (Local ", "Seat number : ": "", "ICN ": "Seoul/Incheon(Incheon) 10JUN19(MON) 16:00 (Local ", "Ticket Number ": "1802326906507 ", "Operated by KE ": "X KSREANAIR ", "From ": "", "Itinerary ": "From "}'
